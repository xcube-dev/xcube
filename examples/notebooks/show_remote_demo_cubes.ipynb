# %% [markdown]
# ## Overview of demo xcube datasets in object storage

# %% [markdown]
# This notebook gives an overview of the demo xcube datasets stored in an object storage bucket. For each xcube dataset the dataset's name, its chunk sizes, how many and which variables are in the cube as well as the first and last time stamp of the dataset are displayed. Additionally, the spatial coverage is displayed as well.
#
# The datsets' name can be used in the other notebooks to open the datasets using the `xcube.core.dsio.open_cube()` function. See example in
# the notebook called [show_remote_demo_cubes.ipynb](./show_remote_demo_cubes.ipynb).
#
# The URL for opening a data cube uses the following format: `'{endpoint_url}/{bucket}/{cube_name}'`. For example, `'https://s3.eu-central-1.amazonaws.com/dcs4cop/bc-sst-sns-l2c-2017_1x704x640.zarr'`.
#
# ---

# %% [markdown]
# Import a helper function that lists data cubes stored in an object storage bucket:

# %%
from show_remote_cubes import show_remote_cubes

# %%
bucket = 'dcs4cop'
endpoint_url = 'https://s3.eu-central-1.amazonaws.com'

# %% [markdown]
# Scan the bucket and return a data frame containing the cubes (this may take a few minutes):

# %%
overview_cubes_table = show_remote_cubes(bucket, endpoint_url)
overview_cubes_table
# Out:
#                                             cube_name  \
# 0                 bc-S2A-flanders-2017_1x214x342.zarr
# 1                 bc-S2A-flanders-2017_1x428x684.zarr
# 2                bc-S2A-flanders-2017_80x107x114.zarr
# 3               bc-cmems-chl-1997-2018_1x704x640.zarr
# 4               bc-cmems-spm-1997-2018_1x704x640.zarr
# 5               bc-cmems-wav-2017-2019_1x704x640.zarr
# 6               bc-olci-sns-l2c-2017_1x1024x1024.zarr
# 7               bc-olci-sns-l2c-2017_1x2560x1408.zarr
# 8                 bc-olci-sns-l2c-2017_493x80x88.zarr
# 9                  bc-sst-sns-l2c-2017_1x704x640.zarr
# 10                bc-sst-sns-l2c-2017_73x120x120.zarr
# 11  cefas-s2-30UVE-30UVF-30UWE-30UWF-2019_1x704x64...
# 12            cefas-uhull-bc-s3-2019_1x1024x1024.zarr
# 13               niva-s3-bergen-2019-1x1024x1024.zarr
# 14                niva-s3-hvaler-2019-1x512x1024.zarr
# 15            niva-s3-oslofjord-2019-1x1024x1024.zarr
# 16       rbins-cmems-SPM-DemoCase-v040_1x128x256.zarr
# 17      rbins-cmems-SPM-DemoCase-v040_42x128x256.zarr
# 18       rbins-cmems-SST-DemoCase-v041_1x128x256.zarr
# 19      rbins-cmems-SST-DemoCase-v041_73x128x128.zarr
# 20  rbins-msi-l2-vito-Chla-SPM-31UET-v041_1x256x25...
# 21  rbins-msi-l2-vito-Chla-SPM-31UET-v041_54x128x1...
# 22   rbins-olci-C2RCCalt-DemoCase-v041_117x64x64.zarr
# 23   rbins-olci-C2RCCalt-DemoCase-v041_1x128x256.zarr
# 24          rbins-seviri-DemoCase-v040_1x128x256.zarr
# 25  starlab-s2-31TCF-31TCG-31TDF-31TDG-31TEF-31TEG...
# 26  starlab-s2-31TCF-31TCG-31TDF-31TDG-31TEF-31TEG...
# 27                   starlab-s3-2019-1x2048x1024.zarr
# 28                    starlab-s3-2019-301x128x64.zarr
# 29           uhull-s2-31UCT-2017-2019_16x256x256.zarr
# 30            uhull-s2-31UCT-2017-2019_1x704x640.zarr
# 31                uhull-s2-31UCV-2019_16x256x256.zarr
# 32                 uhull-s2-31UCV-2019_1x704x640.zarr
# 33                      upmc-s3-2019_1x1024x1024.zarr
#
#                            chunks number_of_variables  \
# 0     time: 1, lat: 214, lon: 342                   2
# 1     time: 1, lat: 428, lon: 684                   2
# 2     time: 6, lat: 107, lon: 114                   2
# 3     time: 1, lat: 704, lon: 640                   1
# 4     time: 1, lat: 704, lon: 640                   1
# 5     time: 1, lat: 704, lon: 640                   6
# 6   time: 1, lat: 1024, lon: 1024                   3
# 7   time: 1, lat: 1408, lon: 2560                   3
# 8     time: 493, lat: 88, lon: 80                   3
# 9     time: 1, lat: 704, lon: 640                   1
# 10   time: 73, lat: 120, lon: 120                   1
# 11    time: 1, lat: 704, lon: 640                   9
# 12  time: 1, lat: 1024, lon: 1024                  17
# 13  time: 1, lat: 1024, lon: 1024                  16
# 14   time: 1, lat: 512, lon: 1024                  16
# 15  time: 1, lat: 1024, lon: 1024                  16
# 16    time: 1, lat: 128, lon: 256                   1
# 17   time: 42, lat: 128, lon: 256                   1
# 18    time: 1, lat: 128, lon: 256                   2
# 19   time: 73, lat: 128, lon: 128                   2
# 20    time: 1, lat: 256, lon: 256                   2
# 21   time: 54, lat: 128, lon: 128                   2
# 22    time: 117, lat: 64, lon: 64                   2
# 23    time: 1, lat: 128, lon: 256                   2
# 24    time: 1, lat: 128, lon: 256                   1
# 25    time: 114, lat: 64, lon: 64                   7
# 26  time: 1, lat: 1024, lon: 1024                   7
# 27  time: 1, lat: 1024, lon: 2048                  10
# 28  time: 1, lat: 1024, lon: 2048                  10
# 29   time: 16, lat: 256, lon: 256                   9
# 30    time: 1, lat: 704, lon: 640                   9
# 31   time: 16, lat: 256, lon: 256                   9
# 32    time: 1, lat: 704, lon: 640                   9
# 33  time: 1, lat: 1024, lon: 1024                  18
#
#                                             variables  start_date    end_date  \
# 0                                  CHL_Bourg, rrs_560  2017-06-01  2017-06-28
# 1                                  CHL_Bourg, rrs_560  2017-01-02  2017-12-28
# 2                                  CHL_Bourg, rrs_560  2017-06-01  2017-06-28
# 3                                                 CHL  1997-09-06  2018-06-29
# 4                                                 SPM  1997-09-04  2018-06-29
# 5                VHM0, VMDR, VSDX, VSDY, VTM02, VTM10  2017-01-01  2019-10-29
# 6                chl_c2rcc, tsm_c2rcc, tur_nechad_665  2017-01-01  2017-12-31
# 7                chl_c2rcc, tsm_c2rcc, tur_nechad_665  2017-01-01  2017-12-31
# 8                chl_c2rcc, tsm_c2rcc, tur_nechad_665  2017-01-01  2017-12-31
# 9                                        analysed_sst  2017-01-01  2017-12-31
# 10                                       analysed_sst  2017-01-01  2017-12-31
# 11  CHL_GILERSON2010_GLOBAL, SPM_NECHAD2010_GLOBAL...  2019-04-01  2019-11-18
# 12  chl_gilerson_2010_red_edge, conc_chl, conc_tsm...  2019-01-01  2019-10-31
# 13  conc_chl, conc_tsm, rrs_17, rrs_3, rrs_4, rrs_...  2019-05-31  2019-08-31
# 14  conc_chl, conc_tsm, rrs_17, rrs_3, rrs_4, rrs_...  2019-05-31  2019-08-31
# 15  conc_chl, conc_tsm, rrs_17, rrs_3, rrs_4, rrs_...  2019-05-31  2019-08-31
# 16                                       SPM-OC5_mean  2017-01-02  2017-12-31
# 17                                       SPM-OC5_mean  2017-01-02  2017-12-31
# 18                        SST_error, SST_mean_Celcius  2017-01-01  2017-12-31
# 19                        SST_error, SST_mean_Celcius  2017-01-01  2017-12-31
# 20                                      Chla, SPM_665  2017-01-16  2017-12-30
# 21                                      Chla, SPM_665  2017-01-16  2017-12-30
# 22                       Chla_EUNOSAT, SPM_Multi_Band  2017-01-01  2017-12-31
# 23                       Chla_EUNOSAT, SPM_Multi_Band  2017-01-01  2017-12-31
# 24                                                SPM  2017-01-01  2017-12-31
# 25  CHL_GILERSON2010_GLOBAL, SPM_NECHAD2010_GLOBAL...  2019-06-02  2019-08-31
# 26  CHL_GILERSON2010_GLOBAL, SPM_NECHAD2010_GLOBAL...  2019-06-02  2019-08-31
# 27  chl_gilerson_2010_red_edge, rtoa_17, rtoa_4, r...  2019-05-31  2019-08-31
# 28  chl_gilerson_2010_red_edge, rtoa_17, rtoa_4, r...  2019-05-31  2019-08-31
# 29  CHL_GILERSON2010_GLOBAL, SPM_NECHAD2010_GLOBAL...  2017-01-02  2019-09-29
# 30  CHL_GILERSON2010_GLOBAL, SPM_NECHAD2010_GLOBAL...  2017-01-02  2019-09-29
# 31  CHL_GILERSON2010_GLOBAL, SPM_NECHAD2010_GLOBAL...  2019-04-02  2019-09-29
# 32  CHL_GILERSON2010_GLOBAL, SPM_NECHAD2010_GLOBAL...  2019-04-02  2019-09-29
# 33  chl_lov_bourgneuf, rrs_17, rrs_3, rrs_4, rrs_5...  2019-01-01  2019-10-31
#
#                                      spatial_coverage
# 0   lon_min: 0.12, lat_min: 50.43, lon_max: 1.7293...
# 1   lon_min: 0.12, lat_min: 50.43, lon_max: 1.7293...
# 2   lon_min: 0.12, lat_min: 50.43, lon_max: 1.7293...
# 3   lon_min: -15.054545454545455, lat_min: 46.9818...
# 4   lon_min: -15.054545454545455, lat_min: 46.9818...
# 5   lon_min: -16.0, lat_min: 44.0, lon_max: 12.0, ...
# 6   lon_min: -16.0, lat_min: 48.0, lon_max: 10.666...
# 7   lon_min: -16.0, lat_min: 48.0, lon_max: 10.666...
# 8   lon_min: -16.0, lat_min: 48.0, lon_max: 10.666...
# 9   lon_min: -16.0, lat_min: 48.0, lon_max: 10.666...
# 10  lon_min: -16.0, lat_min: 48.0, lon_max: 10.666...
# 11  lon_min: -4.465116279069767, lat_min: 53.11627...
# 12  lon_min: -16.0, lat_min: 46.666666666666664, l...
# 13  lon_min: 4.0, lat_min: 58.666666666666664, lon...
# 14  lon_min: 9.333333333333332, lat_min: 58.666666...
# 15  lon_min: 9.333333333333332, lat_min: 58.666666...
# 16  lon_min: 0.5, lat_min: 48.3, lon_max: 4.5, lat...
# 17  lon_min: 0.5, lat_min: 48.3, lon_max: 4.5, lat...
# 18  lon_min: 0.5, lat_min: 48.3, lon_max: 4.5, lat...
# 19  lon_min: 0.5, lat_min: 48.3, lon_max: 4.5, lat...
# 20  lon_min: 0.5, lat_min: 50.5, lon_max: 4.5, lat...
# 21  lon_min: 0.5, lat_min: 50.5, lon_max: 4.5, lat...
# 22  lon_min: 0.5, lat_min: 48.3, lon_max: 4.5, lat...
# 23  lon_min: 0.5, lat_min: 48.3, lon_max: 4.5, lat...
# 24  lon_min: 0.5, lat_min: 48.3, lon_max: 4.5, lat...
# 25  lon_min: 0.5581395348837209, lat_min: 40.46511...
# 26  lon_min: 0.5581395348837209, lat_min: 40.46511...
# 27  lon_min: 0.0, lat_min: 40.0, lon_max: 5.333333...
# 28  lon_min: 0.0, lat_min: 40.0, lon_max: 5.333333...
# 29  lon_min: 0.0, lat_min: 51.25581395348837, lon_...
# 30  lon_min: 0.0, lat_min: 51.25581395348837, lon_...
# 31  lon_min: -0.09302325581395349, lat_min: 53.116...
# 32  lon_min: -0.09302325581395349, lat_min: 53.116...
# 33  lon_min: -2.6666666666666665, lat_min: 44.0, l...
