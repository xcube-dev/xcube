# %% [markdown]
# ## Overview of demo xcube datasets in object storage

# %% [markdown]
# This notebook gives an overview of the demo xcube datasets stored in an object storage bucket. For each xcube dataset the dataset's name, its chunk sizes, how many and which variables are in the cube as well as the first and last time stamp of the dataset are displayed. Additionally, the spatial coverage is displayed as well.
#
# The datsets' name can be used in the other notebooks to open the datasets using the `xcube.core.dsio.open_cube()` function.
#
# The path for opening a cube is structured as following: endpoint_url/bucket/cube_name. For example this could look like: `https://s3.eu-central-1.amazonaws.com/dcs4cop/bc-sst-sns-l2c-2017_1x704x640.zarr`
#
# ---

# %% [markdown]
# Import a helper function that lists data cubes stored in an object storage bucket:

# %%
from show_remote_cubes import show_remote_cubes

# %%
bucket = 'dcs4cop'
endpoint_url = 'https://s3.eu-central-1.amazonaws.com'
region_name = 'eu-central-1'

# %% [markdown]
# Scan the bucket and return a data frame containing the cubes (this may take a few minutes):

# %%
overview_cubes_table = show_remote_cubes(bucket, endpoint_url, region_name)

# %% [markdown]
# Make the variables column wide enough:

# %%
overview_cubes_table.style.set_properties(subset=['variables'], width='300px')
# Out:
# <style  type="text/css" >
#     #T_b45b1ece_2263_11ea_a456_7c7a914aef16row0_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row1_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row2_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row3_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row4_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row5_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row6_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row7_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row8_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row9_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row10_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row11_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row12_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row13_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row14_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row15_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row16_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row17_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row18_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row19_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row20_col3 {
#             width:  300px;
#         }    #T_b45b1ece_2263_11ea_a456_7c7a914aef16row21_col3 {
#             width:  300px;
#         }</style><table id="T_b45b1ece_2263_11ea_a456_7c7a914aef16" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cube_name</th>        <th class="col_heading level0 col1" >chunks</th>        <th class="col_heading level0 col2" >number_of_variables</th>        <th class="col_heading level0 col3" >variables</th>        <th class="col_heading level0 col4" >start_date</th>        <th class="col_heading level0 col5" >end_date</th>        <th class="col_heading level0 col6" >spatial_coverage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b45b1ece_2263_11ea_a456_7c7a914aef16level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row0_col0" class="data row0 col0" >bc-S2A-flanders-2017_1x214x342.zarr</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row0_col1" class="data row0 col1" >time: 1, lat: 214, lon: 342</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row0_col2" class="data row0 col2" >2</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row0_col3" class="data row0 col3" >CHL_Bourg, rrs_560</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row0_col4" class="data row0 col4" >2017-06-01</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row0_col5" class="data row0 col5" >2017-06-28</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row0_col6" class="data row0 col6" >lon_min: 0.12, lat_min: 50.43, lon_max: 1.7293177570093423, lat_max: 51.437</td>
#             </tr>
#             <tr>
#                         <th id="T_b45b1ece_2263_11ea_a456_7c7a914aef16level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row1_col0" class="data row1 col0" >bc-S2A-flanders-2017_80x107x114.zarr</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row1_col1" class="data row1 col1" >time: 6, lat: 107, lon: 114</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row1_col2" class="data row1 col2" >2</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row1_col3" class="data row1 col3" >CHL_Bourg, rrs_560</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row1_col4" class="data row1 col4" >2017-06-01</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row1_col5" class="data row1 col5" >2017-06-28</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row1_col6" class="data row1 col6" >lon_min: 0.12, lat_min: 50.43, lon_max: 1.7293177570093423, lat_max: 51.437</td>
#             </tr>
#             <tr>
#                         <th id="T_b45b1ece_2263_11ea_a456_7c7a914aef16level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row2_col0" class="data row2 col0" >bc-cmems-chl-1997-2018_1x704x640.zarr</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row2_col1" class="data row2 col1" >time: 1, lat: 704, lon: 640</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row2_col3" class="data row2 col3" >CHL</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row2_col4" class="data row2 col4" >1997-09-06</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row2_col5" class="data row2 col5" >2018-06-29</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row2_col6" class="data row2 col6" >lon_min: -15.054545454545455, lat_min: 46.98181818181818, lon_max: 10.036363636363635, lat_max: 62.03636363636363</td>
#             </tr>
#             <tr>
#                         <th id="T_b45b1ece_2263_11ea_a456_7c7a914aef16level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row3_col0" class="data row3 col0" >bc-cmems-spm-1997-2018_1x704x640.zarr</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row3_col1" class="data row3 col1" >time: 1, lat: 704, lon: 640</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row3_col2" class="data row3 col2" >1</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row3_col3" class="data row3 col3" >SPM</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row3_col4" class="data row3 col4" >1997-09-04</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row3_col5" class="data row3 col5" >2018-06-29</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row3_col6" class="data row3 col6" >lon_min: -15.054545454545455, lat_min: 46.98181818181818, lon_max: 10.036363636363635, lat_max: 62.03636363636363</td>
#             </tr>
#             <tr>
#                         <th id="T_b45b1ece_2263_11ea_a456_7c7a914aef16level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row4_col0" class="data row4 col0" >bc-cmems-wav-2017-2019_1x704x640.zarr</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row4_col1" class="data row4 col1" >time: 1, lat: 704, lon: 640</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row4_col2" class="data row4 col2" >6</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row4_col3" class="data row4 col3" >VHM0, VMDR, VSDX, VSDY, VTM02, VTM10</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row4_col4" class="data row4 col4" >2017-01-01</td>
#                         <td id="T_b45b1ece_2263_11ea_a456_7c7a914aef16row4_col5" class="d
