# %% [markdown]
# ## Overview of demo data cubes in cloud

# %% [markdown]
# This notebook giving an overview of the demo xcube datasets stored in an object storage. For each xcube dataset the xcube dataset name, the chunksizes, how many and which variables are in the xcube as well as the first and last time stamp of the xcube dataset are displayed.
# The xcube name can be used in the other notebooks e.g. for reading it from the bucket of an object store or making a subset cube.

# %%
from show_remote_cubes import show_remote_cubes

# %%
overview_cubes_table=show_remote_cubes()

# %%
overview_cubes_table.style.set_properties(subset=['variables'], **{'width': '300px'})
# Out:
# <style  type="text/css" >
#     #T_fe6dc6c4_d62d_11e9_b014_080027ff6761row0_col3 {
#             width:  300px;
#         }    #T_fe6dc6c4_d62d_11e9_b014_080027ff6761row1_col3 {
#             width:  300px;
#         }    #T_fe6dc6c4_d62d_11e9_b014_080027ff6761row2_col3 {
#             width:  300px;
#         }    #T_fe6dc6c4_d62d_11e9_b014_080027ff6761row3_col3 {
#             width:  300px;
#         }    #T_fe6dc6c4_d62d_11e9_b014_080027ff6761row4_col3 {
#             width:  300px;
#         }    #T_fe6dc6c4_d62d_11e9_b014_080027ff6761row5_col3 {
#             width:  300px;
#         }    #T_fe6dc6c4_d62d_11e9_b014_080027ff6761row6_col3 {
#             width:  300px;
#         }    #T_fe6dc6c4_d62d_11e9_b014_080027ff6761row7_col3 {
#             width:  300px;
#         }    #T_fe6dc6c4_d62d_11e9_b014_080027ff6761row8_col3 {
#             width:  300px;
#         }    #T_fe6dc6c4_d62d_11e9_b014_080027ff6761row9_col3 {
#             width:  300px;
# ...
